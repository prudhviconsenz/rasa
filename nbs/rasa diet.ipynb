# %%
from ipstartup import *
path = r"C:\Users\simon\OneDrive\Documents\py\live\enzo_merged\chatbot\results\intent_report.json"
df = pd.read_json(path).T
df = df[df.index.str.find("avg")<0]
df.sort_values("f1-score", ascending=False)
# Out:
# [cellevents:43:INFO]:starting (time=Jan-08 11:32 MainProcess)
#                                         precision    recall  f1-score  \
# add_to_database                               1.0       1.0       1.0
# navigation.turn                               1.0       1.0       1.0
# navigate                                 0.997826  0.997344  0.997585
# weather                                       1.0  0.990741  0.995349
# weather_temperature                      0.962963       1.0  0.981132
# accuracy                                  0.97996   0.97996   0.97996
# music_play                               0.965714  0.960227  0.962963
# dislike                                       0.9       1.0  0.947368
# message_send                                  0.9  0.964286  0.931034
# navigate_search                          0.945205  0.907895  0.926174
# jokes                                    0.833333       1.0  0.909091
# ...

# %%
path = r"C:\Users\simon\OneDrive\Documents\py\live\enzo_merged\chatbot\results\DIETClassifier_report.json"
df = pd.read_json(path).T
df = df[~df.index.isin(["PERSON", "distance", "duration", "number", "ordinal", "phone-number", "time", "temperature"])]
df = df[df.index.str.find("avg")<0]
df.sort_values("f1-score", ascending=False)
# Out:
# [cellevents:43:INFO]:starting (time=Jan-08 11:30 MainProcess)
#                      precision    recall  f1-score support  \
# location.to           0.997839  0.997158  0.997499    8798
# location.from         0.993806  0.994927  0.994366    1774
# location.to_database       1.0  0.964912  0.982143      57
# hotcold               0.961538       1.0  0.980392      25
# address               0.953271  0.953271  0.953271     107
# location              0.868852       1.0  0.929825     106
# unit                       0.9  0.947368  0.923077      19
# location_type         0.956044  0.820755  0.883249     106
# genre                 0.913043  0.777778      0.84      27
# service               0.857143  0.818182  0.837209      22
# topic                 0.956522  0.733333  0.830189      30
# artist                0.792308   0.85124  0.820717     121
# amount                0.666667       1.0       0.8      10
# sort                  0.642857  0.818182      0.72      22
# ...
