# %%
from ipstartup import *
root = r"C:\Users\simon\OneDrive\Documents\py\live\enzo_merged\chatbot"
df = pd.read_csv(f"{root}/docs/zomato.csv")
df = df[["Restaurant Name", "Cuisines"]]
df.columns=["name", "cuisines"]
chars = "[^A-Za-z0-9\,]"
df.name = df.name.str.replace(chars, "")
df.cuisines = df.cuisines.str.replace(chars, "")
df.sample(200).to_csv(f"{root}/actions/zomato200.csv", index=False, encoding="utf8")
df[df.cuisines.str.find("French")>=0]
# Out:
# [cellevents:43:INFO]:starting (time=Jan-10 18:22 MainProcess)
#                                  name                                 cuisines
# 0                      LePetitSouffle                 French,Japanese,Desserts
# 22                         ChezMichou                          FastFood,French
# 67                      Les3Brasseurs               French,Brazilian,Beverages
# 70                    Paris6Classique                                   French
# 128                  ManuelsBreadCafe                         Breakfast,French
# 237                    DuckCityBistro                          American,French
# 259                            Django                                   French
# 458                   RestaurantAndre            French,Mediterranean,European
# 460                              Jaan                                   French
# 461               RhubarbLeRestaurant                                   French
# ...
